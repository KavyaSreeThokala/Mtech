# %%
# Read decimal number from the user
decimal_number = int(input("Enter a decimal number: "))
# Convert using built-in functions
binary = bin(decimal_number)
octal = oct(decimal_number)
hexadecimal = hex(decimal_number)
# Display results
print("Binary equivalent:", binary)
print("Octal equivalent:", octal)
print("Hexadecimal equivalent:", hexadecimal)
# Out:
# Enter a decimal number:  25
# Binary equivalent: 0b11001
# Octal equivalent: 0o31
# Hexadecimal equivalent: 0x19

# %%
# Read a string representing a floating-point number
num_str = input("Enter a floating-point number: ")
# Convert string to float
num = float(num_str)
# Add 10.5 to the number
result = num + 10.5
# Display the result
print("Result after adding 10.5:", result)
# Out:
# Enter a floating-point number:  25.67
# Result after adding 10.5: 36.17
