# %%
import numpy as np
import matplotlib.pyplot as plt

# Dataset
X = np.array([1, 2, 3, 4, 5, 6])
y = np.array([2, 3, 5, 6, 8, 9])

# Initialize parameters
m = 0.0
c = 0.0

# Hyperparameters
alpha = 0.01
epochs = 1000
n = len(X)

losses = []

# Gradient Descent loop
for i in range(epochs):
    y_pred = m * X + c
    
    # Mean Squared Error
    loss = (1/n) * np.sum((y - y_pred) ** 2)
    losses.append(loss)
    
    # Gradients
    dm = (-2/n) * np.sum(X * (y - y_pred))
    dc = (-2/n) * np.sum(y - y_pred)
    
    # Update
    m = m - alpha * dm
    c = c - alpha * dc

print("Final slope (m):", m)
print("Final intercept (c):", c)

# Plot data and regression line
plt.scatter(X, y)
plt.plot(X, m * X + c)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Linear Regression using Gradient Descent")
plt.show()

# Plot loss curve
plt.plot(losses)
plt.xlabel("Epochs")
plt.ylabel("Loss (MSE)")
plt.title("Loss vs Epochs")
plt.show()
# Out:
# Final slope (m): 1.4574841138267094
# Final intercept (c): 0.3985390123970645
